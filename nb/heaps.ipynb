# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
leftist_heap_insert = pd.read_csv("../leftist_heap_insert.csv", header=None)
binary_heap_insert = pd.read_csv("../binary_heap_vec_insert.csv", header=None)
leftist_heap_insert_random = pd.read_csv("../leftist_heap_insert_random.csv", header=None)
binary_heap_insert_random = pd.read_csv("../binary_heap_vec_insert_random.csv", header=None)

# %%
leftist_heap_insert
# Out:
#         0         1
# 0   10000  0.002443
# 1   50000  0.009601
# 2  100000  0.017048
# 3  200000  0.027463
# 4  300000  0.026877
# 5  400000  0.030327
# 6  500000  0.039061

# %%
binary_heap_insert
# Out:
#         0         1
# 0   10000  0.000168
# 1   50000  0.000517
# 2  100000  0.000998
# 3  200000  0.001902
# 4  300000  0.002336
# 5  400000  0.002662
# 6  500000  0.004307

# %%
fig, ax = plt.subplots(figsize=(12, 8))


leftist_heap_insert.plot.line(x=0, y=1, label="Leftist heap", marker='o', ax=ax)
binary_heap_insert.plot.line(x=0, y=1, label="Binary heap", marker='o', ax=ax)

leftist_heap_insert_random.plot.line(x=0, y=1, label="Leftist heap (random)", marker='o', ax=ax)
binary_heap_insert_random.plot.line(x=0, y=1, label="Binary heap (random)", marker='o', ax=ax)


ax.set_title("Heap insert")
ax.set_ylabel("Time [seconds]")
ax.set_xlabel("N")

ax.grid()
# plt.yscale('log')
#plt.xscale('log')
